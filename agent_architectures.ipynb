# %% [markdown]
# # Build a Multi-Agent Systems
# In this notebook, we'll:
# - ✅ Configure the API key to use the Gemini model
# - ✅ Learn when to use multi-agent systems in [Agent Development Kit (ADK)](https://google.github.io/adk-docs/)
# - ✅ Build a system using an LLM as a "manager"
# - ✅ Learn three core workflow patterns (Sequential, Parallel, and Loop) to coordinate the agent teams

# %% [markdown]
# ## Part 1: Add Gemini API key to the env
#
# This notebook uses the Gemini API, which requires authentication.
#
# 1. Get your API key
#
# If you don't have one already, create an API key in Google AI Studio.
#
# 2. Add the key to env and load as shown in the script

# %%
from dotenv import load_dotenv
import os

load_dotenv()

google_api_key = os.environ.get("GOOGLE_API_KEY")
if not google_api_key:
    print(
        "GOOGLE_API_KEY is not set. Create one in Google AI Studio "
        "(https://aistudio.google.com/) and add it to your env or .env file."
    )
    raise SystemExit("Set GOOGLE_API_KEY and rerun this cell.")

print("✅ GOOGLE_API_KEY loaded.")
# Out:
# ✅ GOOGLE_API_KEY loaded.

# %% [markdown]
# ### validate the api key

# %%
from google import genai
from google.genai import types

client = genai.Client(api_key=google_api_key)

try:
    _ = client.models.generate_content(
        model="gemini-2.5-flash-lite",
        contents="ping",
        config=types.GenerateContentConfig(max_output_tokens=1),
    )
    print("✅ API key validated with Gemini.")
except Exception as err:
    raise SystemExit(f"API key validation failed: {err}")
# Out:
# ✅ API key validated with Gemini.

# %% [markdown]
# ### Import ADK components

# %%
from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %% [markdown]
# ## Part 2: Why multi-agent systems? + Design a multi-agent
# **The Problem: The "Do-It-All" Agent**
# While single agents can accomplish many tasks, they quickly reach limitations as tasks grow in complexity. A monolithic agent that attempts to handle research, writing, editing, and fact-checking simultaneously faces several challenges:
# - Bloated and confusing instruction prompts
# - Difficulty in debugging (unclear which part failed)
# - Maintenance challenges
# - Higher risk of producing unreliable results
#
# **The Solution: A Team of Specialists**
# Rather than relying on a single agent for every task, a **multi-agent system** employs several specialized agents that work together—just like a collaborative team. Each agent has one clear responsibility (for example, one agent focuses on research, another handles writing). This specialization leads to:
# - Easier construction and testing of individual agents
# - Greater reliability and maintainability
# - Enhanced overall system performance through collaboration
#
# For further details, refer to the [LLM agents in ADK documentation](https://google.github.io/adk-docs/agents/llm-agents/).
# **Architecture: Single Agent vs Multi-Agent Team**

# %% [markdown]
# ### Example: Research + Summarization System
# Let's build a system with two specialized agents:
#
# 1. **Research Agent** - Searches for information using Google Search
# 2. **Summarizer Agent** - Creates concise summaries from research findings
#
# ### Other Multi-Agent System Examples
# <!-- #
# # Here are several ideas for multi-agent systems composed of specialized agents:
# #
# # 1. **Question Answering System**
# #    - **Retriever Agent**: Finds relevant documents or passages from a knowledge base.
# #    - **Reader Agent**: Extracts and formulates a direct answer from the retrieved text.
# #
# # 2. **Content Generation Pipeline**
# #    - **Research Agent**: Gathers key facts and background information.
# #    - **Writer Agent**: Generates a draft article or story based on research.
# #    - **Editor Agent**: Refines grammar, style, and coherence.
# #
# # 3. **Multi-Modal Assistant**
# #    - **Image Analysis Agent**: Interprets and describes uploaded images.
# #    - **Text Summarization Agent**: Summarizes content from images and user input.
# #    - **Fact-Checking Agent**: Verifies the accuracy of generated statements.
# #
# # 4. **Customer Support System**
# #    - **Intent Recognition Agent**: Classifies user requests.
# #    - **FAQ Lookup Agent**: Searches a database for relevant answers.
# #    - **Escalation Agent**: Determines when to hand off to a human or higher-level agent.
# #
# # 5. **Creative Design Team**
# #    - **Idea Generator Agent**: Proposes new concepts or approaches.
# #    - **Critique Agent**: Reviews and suggests improvements. -->

# %%
# Research Agent: Its job is to use the google_search tool and present findings.
research_agent = Agent(
    name="ResearchAgent",
    model="gemini-2.5-flash-lite",
    instruction="""You are a specialized research agent. Your only job is to use the
    google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.""",
    tools=[google_search],
    output_key="research_findings", # The result of this agent will be stored in the session state with this key.
)

print("✅ research_agent created.")
# Out:
# ✅ research_agent created.

# %%
# Summarizer Agent: Its job is to summarize the text it receives.
summarizer_agent = Agent(
    name="SummarizerAgent",
    model="gemini-2.5-flash-lite",
    # The instruction is modified to request a bulleted list for a clear output format.
    instruction="""Read the provided research findings: {research_findings}
Create a concise summary as a bulleted list with 3-5 key points.""",
    output_key="final_summary",
)

print("✅ summarizer_agent created.")
# Out:
# ✅ summarizer_agent created.

# %% [markdown]
# Then we bring the agents together under a root agent, or coordinator:

# %%
# Root Coordinator: Orchestrates the workflow by calling the sub-agents as tools.
root_agent = Agent(
    name="ResearchCoordinator",
    model="gemini-2.5-flash-lite",
    # This instruction tells the root agent HOW to use its tools (which are the other agents).
    instruction="""You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
1. First, you MUST call the `ResearchAgent` tool to find relevant information on the topic provided by the user.
2. Next, after receiving the research findings, you MUST call the `SummarizerAgent` tool to create a concise summary.
3. Finally, present the final summary clearly to the user as your response.""",
    # We wrap the sub-agents in `AgentTool` to make them callable tools for the root agent.
    tools=[
        AgentTool(research_agent),
        AgentTool(summarizer_agent)
    ],
)

print("✅ root_agent created.")
# Out:
# ✅ root_agent created.

# %% [markdown]
# Lets run the agent and ask about a topic

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("What are the latest advancements of India in the field of AI?")
# Out:
#  ### Created new session: debug_session_id
#
# User > What are the latest advancements of India in the field of AI?
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# ResearchCoordinator > India has been making significant strides in Artificial Intelligence (AI). The government has launched the IndiaAI Mission with a substantial budget to position India as a global AI leader, focusing on accessibility, data enhancement, and industry collaboration. A key development is the emphasis on indigenous AI, including models like BharatGen AI that support 22 Indian languages, and Sarvam AI working towards a sovereign AI ecosystem. India is also expanding its AI integration through Centers of Excellence in critical sectors, promoting state-level AI centers, and incorporating AI into governance for better efficiency and service delivery. Furthermore, the country boasts a dynamic AI startup scene and a strong talent pool, ranking highly in global AI skills and research participation.

# %% [markdown]
# Congratulations! We've just created your first multi-agent system—a setup where a single "coordinator" agent orchestrates a workflow by managing sub-agents. This pattern is both powerful and flexible for many use cases.
#
# ‼️ However, relying on an LLM's instructions to control the order can sometimes be unpredictable. Next, we'll explore a different pattern that gives you guaranteed, step-by-step execution.

# %% [markdown]
# ## Part 3 Sequential Workflows - The Assembly Line
#
# **The Problem: Unpredictable Order**
#
# The previous multi-agent system worked, but it relied on a **detailed instruction prompt** to force the LLM to run steps in order. This can be unreliable. A complex LLM might decide to skip a step, run them in the wrong order, or get "stuck," making the process unpredictable.
#
# **The Solution: A Fixed Pipeline**
#
# When you need tasks to happen in a **guaranteed, specific order**, you can use a `SequentialAgent`. This agent acts like an assembly line, running each sub-agent in the exact order you list them. The output of one agent automatically becomes the input for the next, creating a predictable and reliable workflow.
#
# **Use Sequential when:** Order matters, you need a linear pipeline, or each step builds on the previous one.
#
# To learn more, check out the documentation related to [sequential agents in ADK](https://google.github.io/adk-docs/agents/workflow-agents/sequential-agents/).

# %% [markdown]
# ### Example: Blog Post Creation with Sequential Agents
#
# Let's build a system with three specialized agents:
#
# 1. **Outline Agent** - Creates a blog outline for a given topic
# 2. **Writer Agent** - Writes a blog post
# 3. **Editor Agent** - Edits a blog post draft for clarity and structure

# %%
# Outline Agent: Creates the initial blog post outline.
outline_agent = Agent(
    name="OutlineAgent",
    model="gemini-2.5-flash-lite",
    instruction="""Create a blog outline for the given topic with:
    1. A catchy headline
    2. An introduction hook
    3. 3-5 main sections with 2-3 bullet points for each
    4. A concluding thought""",
    output_key="blog_outline", # The result of this agent will be stored in the session state with this key.
)

print("✅ outline_agent created.")
# Out:
# ✅ outline_agent created.

# %%
# Writer Agent: Writes the full blog post based on the outline from the previous agent.
writer_agent = Agent(
    name="WriterAgent",
    model="gemini-2.5-flash-lite",
    instruction="""Following this outline strictly: {blog_outline}
    Write a brief, 200 to 300-word blog post with an engaging and informative tone.""",
    output_key="blog_draft", # The result of this agent will be stored with this key.
)

print("✅ writer_agent created.")
# Out:
# ✅ writer_agent created.

# %%
# Editor Agent: Edits and polishes the draft from the writer agent.
editor_agent = Agent(
    name="EditorAgent",
    model="gemini-2.5-flash-lite",
    instruction="""Edit this draft: {blog_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow and sentence structure, and enhancing overall clarity.""",
    output_key="final_blog", # This is the final output of the entire pipeline.
)

print("✅ editor_agent created.")
# Out:
# ✅ editor_agent created.

# %% [markdown]
# Then we bring the agents together under a sequential agent, which runs the agents in the order that they are listed:

# %%
root_agent = SequentialAgent(
    name="BlogPipeline",
    sub_agents=[outline_agent, writer_agent, editor_agent],
)

print("✅ Sequential Agent created.")
# Out:
# ✅ Sequential Agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("Write a blog post about the role of Indian government in AI.")
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a blog post about the role of Indian government in AI.
# OutlineAgent > ## Blog Post Outline: The Indian Government's AI Ascendancy
#
# **Headline:** India's AI Ambitions: How the Government is Shaping the Future of Artificial Intelligence
#
# **Introduction Hook:** From smart cities to digital healthcare, Artificial Intelligence is no longer a futuristic fantasy in India – it's a rapidly unfolding reality. But what role is the Indian government playing in this technological revolution? Dive into how policy, investment, and a vision for "AI for All" are propelling India onto the global AI stage.
#
# ---
#
# **Main Section 1: Policy & Vision – Laying the AI Groundwork**
#
# *   **National Strategy for AI:** Explore the government's overarching strategy, emphasizing its goals for economic growth, social development, and making India a global leader in AI research and application.
# *   **Ethical AI Frameworks:** Discuss the government's focus on responsible AI development, including initiatives addressing data privacy, security, and the prevention of bias.
# *   **Regulatory Sandboxes:** Highlight how the government is creating safe spaces for AI innovation, allowing businesses to test new AI technologies under relaxed regulations.
#
# **Main Section 2: Investment & Infrastructure – Fueling AI Growth**
#
# *   **Funding for Research & Development:** Detail government grants, funding schemes, and the establishment of AI research hubs to foster cutting-edge AI advancements.
# *   **Digital India Initiative:** Explain how broader digital infrastructure projects are creating the foundational elements necessary for widespread AI adoption.
# *   **Data Infrastructure Development:** Discuss government efforts to build robust and accessible data infrastructure, crucial for training and deploying AI models effectively.
#
# **Main Section 3: Key Sectoral Applications – AI for Public Good**
#
# *   **Healthcare Transformation:** Showcase government-backed AI initiatives in diagnostics, drug discovery, personalized medicine, and improving healthcare accessibility in rural areas.
# *   **Agriculture Modernization:** Explore how AI is being leveraged for precision farming, crop yield prediction, pest control, and enhancing farmer incomes.
# *   **Smart Cities & Governance:** Discuss the role of AI in improving urban management, traffic flow, waste management, and delivering more efficient public services.
#
# **Main Section 4: Skill Development & Talent Pool – Empowering the AI Workforce**
#
# *   **AI Education & Training Programs:** Outline government-led initiatives to integrate AI into educational curricula and provide specialized training for students and professionals.
# *   **Incubators & Accelerators:** Highlight government support for startups and entrepreneurs in the AI space, nurturing new talent and fostering innovation.
# *   **International Collaborations:** Discuss partnerships with global institutions to share knowledge, attract talent, and stay at the forefront of AI research.
#
# ---
#
# **Concluding Thought:** The Indian government's proactive and multi-faceted approach to Artificial Intelligence is not just about technological advancement; it's about harnessing AI's potential to create a more inclusive, efficient, and prosperous future for all its citizens. As these initiatives mature, India is poised to become a significant force in the global AI landscape.
# WriterAgent > ## India's AI Ambitions: How the Government is Shaping the Future of Artificial Intelligence
#
# Artificial Intelligence (AI) is no longer a distant dream in India; it's a rapidly unfolding reality, touching everything from smart cities to digital healthcare. But what's the driving force behind this technological leap? It's the Indian government's proactive and strategic engagement, propelling the nation towards an "AI for All" future and onto the global stage.
#
# The government has laid a robust foundation through its National Strategy for AI, aiming for significant economic growth and social development. Crucially, this vision emphasizes responsible AI, with a focus on ethical frameworks to ensure data privacy, security, and the prevention of bias. To foster innovation, regulatory sandboxes are being established, providing a safe environment for businesses to test cutting-edge AI technologies.
#
# Fueling this growth is substantial investment. Funding for research and development, coupled with the establishment of AI research hubs, is accelerating breakthroughs. The ambitious Digital India initiative is building the essential digital infrastructure, while dedicated efforts are underway to develop robust data infrastructure, vital for effective AI model training and deployment.
#
# These advancements are translating into tangible benefits across key sectors. AI is transforming healthcare through improved diagnostics and accessibility, modernizing agriculture with precision farming techniques, and enhancing governance in smart cities by optimizing services. Furthermore, the government is actively building India's AI talent pool through educational programs, incubators, and international collaborations.
#
# The Indian government's multi-faceted approach to AI is not merely about technological prowess; it's a commitment to leveraging AI for a more inclusive and prosperous future for all its citizens, positioning India as a formidable player in the global AI landscape.
# EditorAgent > ## India's AI Ambitions: How the Government is Shaping the Future of Artificial Intelligence
#
# Artificial Intelligence (AI) is no longer a futuristic fantasy in India; it's a rapidly unfolding reality, impacting everything from smart cities to digital healthcare. But what's the driving force behind this technological leap? It's the Indian government's proactive and strategic engagement, propelling the nation towards an "AI for All" future and onto the global stage.
#
# The government has laid a robust foundation through its **National Strategy for AI**, which outlines ambitious goals for significant economic growth, broad social development, and establishing India as a leader in AI research and application. Crucially, this vision emphasizes **responsible AI development**. Initiatives are in place to establish ethical frameworks that prioritize data privacy, robust security measures, and the prevention of bias in AI systems. To further foster innovation, **regulatory sandboxes** are being established. These act as safe, controlled environments where businesses can test cutting-edge AI technologies under relaxed regulations, encouraging experimentation and faster development.
#
# Fueling this ambitious growth is substantial **investment in research and development**. Through dedicated funding schemes and the establishment of AI research hubs, the government is accelerating breakthroughs in the field. The ongoing **Digital India initiative** is vital, building the essential digital infrastructure that underpins widespread AI adoption. Alongside this, dedicated efforts are underway to develop **robust data infrastructure**. This accessible and well-managed data is the lifeblood of effective AI model training and deployment.
#
# These advancements are translating into tangible benefits across key sectors. In **healthcare**, AI is transforming diagnostics, improving accessibility, and even aiding in drug discovery. **Agriculture** is being modernized through precision farming techniques, crop yield predictions, and pest control, all aimed at enhancing farmer incomes. **Smart cities and governance** are also seeing improvements, with AI optimizing urban management, traffic flow, waste management, and delivering more efficient public services.
#
# Recognizing that technological progress requires skilled individuals, the government is actively focused on building India's **AI talent pool**. This involves integrating AI into educational curricula, launching specialized **training programs**, and supporting **incubators and accelerators** that nurture AI startups and entrepreneurs. Furthermore, fostering **international collaborations** with global institutions is key to sharing knowledge, attracting talent, and ensuring India remains at the forefront of AI research.
#
# The Indian government's multi-faceted approach to Artificial Intelligence is not merely about technological prowess; it's a deep commitment to leveraging AI's potential to create a more inclusive, efficient, and prosperous future for all its citizens. As these initiatives continue to mature, India is steadily positioning itself as a formidable and influential player in the global AI landscape.

# %% [markdown]
# ---
# ## Part 4 Parallel Workflows - Independent Researchers
#
# **The Problem: The Bottleneck**
#
# The previous sequential agent is great, but it's an assembly line. Each step must wait for the previous one to finish. What if you have several tasks that are **not dependent** on each other? For example, researching three *different* topics. Running them in sequence would be slow and inefficient, creating a bottleneck where each task waits unnecessarily.
#
# **The Solution: Concurrent Execution**
#
# When you have independent tasks, you can run them all at the same time using a `ParallelAgent`. This agent executes all of its sub-agents concurrently, dramatically speeding up the workflow. Once all parallel tasks are complete, you can then pass their combined results to a final 'aggregator' step.
#
# **Use Parallel when:** Tasks are independent, speed matters, and you can execute concurrently.
#
# To learn more, check out the documentation related to [parallel agents in ADK](https://google.github.io/adk-docs/agents/workflow-agents/parallel-agents/).

# %% [markdown]
# ### Example: Parallel Multi-Topic Research
#
# Let's build a system with four agents:
#
# 1. **Tech Researcher** - Researches AI/ML news and trends
# 2. **Health Researcher** - Researches recent medical news and trends
# 3. **Finance Researcher** - Researches finance and fintech news and trends
# 4. **Aggregator Agent** - Combines all research findings into a single summary

# %%
# Tech Researcher: Focuses on AI and ML trends.
tech_researcher = Agent(
    name="TechResearcher",
    model="gemini-2.5-flash-lite",
    instruction="""Research the latest AI/ML trends. Include 3 key developments,
the main companies involved, and the potential impact. Keep the report very concise (100 words).""",
    tools=[google_search],
    output_key="tech_research", # The result of this agent will be stored in the session state with this key.
)

print("✅ tech_researcher created.")
# Out:
# ✅ tech_researcher created.

# %%
# Health Researcher: Focuses on medical breakthroughs.
health_researcher = Agent(
    name="HealthResearcher",
    model="gemini-2.5-flash-lite",
    instruction="""Research recent medical breakthroughs. Include 3 significant advances,
their practical applications, and estimated timelines. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="health_research", # The result will be stored with this key.
)

print("✅ health_researcher created.")
# Out:
# ✅ health_researcher created.

# %%
# Finance Researcher: Focuses on fintech trends.
finance_researcher = Agent(
    name="FinanceResearcher",
    model="gemini-2.5-flash-lite",
    instruction="""Research current fintech trends. Include 3 key trends,
their market implications, and the future outlook. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="finance_research", # The result will be stored with this key.
)

print("✅ finance_researcher created.")
# Out:
# ✅ finance_researcher created.

# %%
# The AggregatorAgent runs *after* the parallel step to synthesize the results.
aggregator_agent = Agent(
    name="AggregatorAgent",
    model="gemini-2.5-flash-lite",
    # It uses placeholders to inject the outputs from the parallel agents, which are now in the session state.
    instruction="""Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_research}
    
    **Health Breakthroughs:**
    {health_research}
    
    **Finance Innovations:**
    {finance_research}
    
    Your summary should highlight common themes, surprising connections, and the most important key takeaways from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary", # This will be the final output of the entire system.
)

print("✅ aggregator_agent created.")
# Out:
# ✅ aggregator_agent created.

# %%
# The ParallelAgent runs all its sub-agents simultaneously.
parallel_research_team = ParallelAgent(
    name="ParallelResearchTeam",
    sub_agents=[tech_researcher, health_researcher, finance_researcher],
)

# This SequentialAgent defines the high-level workflow: run the parallel team first, then run the aggregator.
root_agent = SequentialAgent(
    name="ResearchSystem",
    sub_agents=[parallel_research_team, aggregator_agent],
)

print("✅ Parallel and Sequential Agents created.")
# Out:
# ✅ Parallel and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("Compare India and China on Tech, Health, and Finance")
# Out:
#  ### Created new session: debug_session_id
#
# User > Compare India and China on Tech, Health, and Finance
# FinanceResearcher > Here's a comparison of India and China across Technology, Health, and Finance:
#
# **Technology:**
#
# *   **India:** A global IT services and outsourcing hub, with a burgeoning startup ecosystem and strong growth in AI, cloud computing, and cybersecurity. The government's "Digital India" initiative further fuels growth and digital literacy.
# *   **China:** A tech powerhouse with dominant players in e-commerce, social media, AI, and telecommunications. China is a leader in emerging technologies like 5G and IoT, with massive data utilization driving AI development.
#
# **Health:**
#
# *   **India:** A rapidly growing healthcare sector, driven by increasing demand, private sector investment, and a focus on medical tourism and telemedicine. Government spending is also increasing, aiming to improve accessibility and quality.
# *   **China:** The world's second-largest healthcare market, with a dominant state-owned hospital system and a growing private sector catering to higher quality services. The "Healthy China 2030" initiative aims for significant market expansion.
#
# **Finance:**
#
# *   **India:** Experiencing major transformation with rapid digital finance expansion, increasing domestic savings, and growth in NBFCs. The financial services sector is poised for significant growth, with a focus on financial inclusion and digital adoption.
# *   **China:** A maturing and large financial system, with banks dominating but also a growing capital market and asset management sector. The country is opening up its financial markets and fostering innovation, with fintech playing a crucial role.
# HealthResearcher > ## India vs. China: A Comparative Overview (Tech, Health, Finance)
#
# **Technology:** China leads significantly in the number of high-tech companies and overall technological advancement, with major players like Alibaba and Tencent dominating. India, while producing many engineers, has historically lacked platforms for them to innovate, though its startup ecosystem is growing. China is also a more established AI powerhouse, leveraging massive datasets and state-driven strategies, whereas India is rapidly emerging as an agile challenger focusing on inclusive AI applications. However, India's tech sector is seen as more fragmented and competitive, with a hands-off regulatory approach fostering innovation.
#
# **Health:** China has demonstrated more rapid and widespread health improvements than India, including higher life expectancy and lower infant/child mortality rates. India faces a higher burden of infectious diseases, partly due to challenges in providing basic healthcare to large urban slum populations. While both nations are experiencing a rise in non-communicable diseases, China's health system has generally been more successful in improving population health outcomes. China's state has traditionally supported more healthcare costs, whereas India has relied more on private insurance.
#
# **Finance:** China's GDP is significantly larger than India's, both overall and per capita. China transitioned to a market-oriented economy earlier and more rapidly than India, which has focused more on the services sector while China excelled in manufacturing. While both economies face debt challenges, China's public debt is more complex due to hidden local government debt. India's economy is projected to grow faster than China's in the coming years, driven by demographics. Investors have recently shown renewed interest in China due to stimulus packages and cheap valuations, though India's stock market has also seen significant growth.
# TechResearcher > **India vs. China: A Comparative Overview of Tech, Health, and Finance Sectors**
#
# **Technology:**
# China is a global tech powerhouse, leading in AI, 5G, and consumer electronics, with significant government investment driving innovation. India's tech sector is booming, projected to reach $350 billion in revenue by 2026, driven by digital transformation and government initiatives like "Digital India." Key Indian trends include AI/ML, cloud computing, cybersecurity, and the nascent 5G rollout. China excels in large-scale deployment of emerging technologies like AI, IoT, and blockchain, with companies like Huawei, Baidu, JD, and Tencent at the forefront. India's IT industry is growing, with a focus on AI/ML integration across sectors and a "hardware renaissance."
#
# **Health:**
# China's healthcare market is the world's second-largest, exceeding $1 trillion, driven by an aging population, rising incomes, and the "Healthy China 2030" initiative. Key areas include pharmaceuticals, medical devices, and digital healthcare. India's healthcare sector is also experiencing robust growth, valued at $178 billion in 2023, with a strong focus on affordability and quality. Trends include integrated wellness ecosystems, "actionable AI," and "diagnostics-at-home." India is a leader in pharmaceuticals and medical tourism.
#
# **Finance:**
# China's fintech sector is the world's largest, with a transaction value exceeding $4 trillion in 2023, dominated by mobile payments (Alipay, WeChat Pay) and a strong focus on financial inclusion. Key drivers include high mobile penetration, regulatory support, and consumer demand for digital solutions. India's fintech sector is rapidly expanding, with a valuation of $31 billion in 2021 projected to reach $150 billion by 2025, driven by digital payments, AI/ML, and a growing startup ecosystem. Trends in India include embedded finance, BNPL, and regtech. Major players in China's fintech include Ant Group and Tencent. India has seen the rise of neobanks and insurtech.
# AggregatorAgent > ## Executive Summary: India vs. China - A Comparative Sectoral Analysis
#
# Both India and China are rapidly advancing across technology, health, and finance, but with distinct strengths and approaches. China leads as a global tech powerhouse, particularly in AI, 5G, and large-scale deployment, driven by significant government investment and major corporations. India's tech sector is a burgeoning IT services hub with a growing startup ecosystem focused on AI/ML integration and digital transformation, supported by initiatives like "Digital India."
#
# In healthcare, China has achieved broader population health improvements and boasts the world's second-largest market, driven by an aging demographic and a strong state role. India's healthcare sector is growing rapidly, focusing on affordability, medical tourism, and emerging trends like "diagnostics-at-home," with a greater reliance on private insurance.
#
# Financially, China dominates with the world's largest fintech sector, heavily reliant on mobile payments. India's fintech sector is rapidly expanding, fueled by digital payments, a vibrant startup scene, and a focus on financial inclusion through embedded finance and neobanks. While China's economy is larger, India's is projected for faster future growth due to its demographics, signaling dynamic shifts across these critical sectors.

# %% [markdown]
# ## Part 5  Loop Workflows - The Refinement Cycle
#
# **The Problem: One-Shot Quality**
#
# All the workflows we've seen so far run from start to finish. The `SequentialAgent` and `ParallelAgent` produce their final output and then stop. This 'one-shot' approach isn't good for tasks that require refinement and quality control. What if the first draft of our story is bad? We have no way to review it and ask for a rewrite.
#
# **The Solution: Iterative Refinement**
#
# When a task needs to be improved through cycles of feedback and revision, you can use a `LoopAgent`. A `LoopAgent` runs a set of sub-agents repeatedly *until a specific condition is met or a maximum number of iterations is reached.* This creates a refinement cycle, allowing the agent system to improve its own work over and over.
#
# **Use Loop when:** Iterative improvement is needed, quality refinement matters, or you need repeated cycles.
#
# To learn more, check out the documentation related to [loop agents in ADK](https://google.github.io/adk-docs/agents/workflow-agents/loop-agents/).

# %% [markdown]
# ### Example: Iterative Story Refinement
#
# Let's build a system with two agents:
#
# 1. **Writer Agent** - Writes a draft of a short story
# 2. **Critic Agent** - Reviews and critiques the short story to suggest improvements

# %%
# This agent runs ONCE at the beginning to create the first draft.
initial_writer_agent = Agent(
    name="InitialWriterAgent",
    model="gemini-2.5-flash-lite",
    instruction="""Based on the user's prompt, write the first draft of a short story (around 100-150 words).
    Output only the story text, with no introduction or explanation.""",
    output_key="current_story", # Stores the first draft in the state.
)

print("✅ initial_writer_agent created.")
# Out:
# ✅ initial_writer_agent created.

# %%
# This agent's only job is to provide feedback or the approval signal. It has no tools.
critic_agent = Agent(
    name="CriticAgent",
    model="gemini-2.5-flash-lite",
    instruction="""You are a constructive story critic. Review the story provided below.
    Story: {current_story}
    
    Evaluate the story's plot, characters, and pacing.
    - If the story is well-written and complete, you MUST respond with the exact phrase: "APPROVED"
    - Otherwise, provide 2-3 specific, actionable suggestions for improvement.""",
    output_key="critique", # Stores the feedback in the state.
)

print("✅ critic_agent created.")
# Out:
# ✅ critic_agent created.

# %% [markdown]
# Now, we need a way for the loop to actually stop based on the critic's feedback. The `LoopAgent` itself doesn't automatically know that "APPROVED" means "stop."
#
# We need an agent to give it an explicit signal to terminate the loop.
#
# We do this in two parts:
#
# 1. A simple Python function that the `LoopAgent` understands as an "exit" signal.
# 2. An agent that can call that function when the right condition is met.
#
# First, you'll define the `exit_loop` function:

# %%
# This is the function that the RefinerAgent will call to exit the loop.
def exit_loop():
    """Call this function ONLY when the critique is 'APPROVED', indicating the story is finished and no more changes are needed."""
    return {"status": "approved", "message": "Story approved. Exiting refinement loop."}

print("✅ exit_loop function created.")
# Out:
# ✅ exit_loop function created.

# %%
# This agent refines the story based on critique OR calls the exit_loop function.
refiner_agent = Agent(
    name="RefinerAgent",
    model="gemini-2.5-flash-lite",
    instruction="""You are a story refiner. You have a story draft and critique.
    
    Story Draft: {current_story}
    Critique: {critique}
    
    Your task is to analyze the critique.
    - IF the critique is EXACTLY "APPROVED", you MUST call the `exit_loop` function and nothing else.
    - OTHERWISE, rewrite the story draft to fully incorporate the feedback from the critique.""",
    
    output_key="current_story", # It overwrites the story with the new, refined version.
    tools=[FunctionTool(exit_loop)], # The tool is now correctly initialized with the function reference.
)

print("✅ refiner_agent created.")
# Out:
# ✅ refiner_agent created.

# %% [markdown]
# Then we bring the agents together under a loop agent, which is itself nested inside of a sequential agent.
#
# This design ensures that the system first produces an initial story draft, then the refinement loop runs up to the specified number of `max_iterations`:

# %%
# The LoopAgent contains the agents that will run repeatedly: Critic -> Refiner.
story_refinement_loop = LoopAgent(
    name="StoryRefinementLoop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=2, # Prevents infinite loops
)

# The root agent is a SequentialAgent that defines the overall workflow: Initial Write -> Refinement Loop.
root_agent = SequentialAgent(
    name="StoryPipeline",
    sub_agents=[initial_writer_agent, story_refinement_loop],
)

print("✅ Loop and Sequential Agents created.")
# Out:
# ✅ Loop and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("Write a short story about a lighthouse keeper who discovers a mysterious, glowing map")
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a short story about a lighthouse keeper who discovers a mysterious, glowing map
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~/Work/AgenticAI/.agenticai/lib/python3.13/site-packages/google/adk/models/google_llm.py:241, in Gemini.generate_content_async(self, llm_request, stream)
#     240 else:
# --> 241   response = await self.api_client.aio.models.generate_content(
#     242       model=llm_request.model,
#     243       contents=llm_request.contents,
#     244       config=llm_request.config,
#     245   )
#     246   logger.info('Response received from the model.')
#
# File ~/Work/AgenticAI/.agenticai/lib/python3.13/site-packages/google/genai/models.py:7045, in AsyncModels.generate_content(self, model, contents, config)
#    7044 while remaining_remote_calls_afc > 0:
# -> 7045   response = await self._generate_content(
#    7046       model=model, contents=contents, config=parsed_config
#    7047   )
#    7048   remaining_remote_calls_afc -= 1
#
# File ~/Work/AgenticAI/.agenticai/lib/python3.13/site-packages/google/genai/models.py:5851, in AsyncModels._generate_content(self, model, contents, config)
#    5849 request_dict = _common.encode_unserializable_types(request_dict)
# -> 5851 response = await self._api_client.async_request(
#    5852     'post', path, request_dict, http_options
#    5853 )
#    5855 if config is not None and getattr(
#    5856     config, 'should_return_http_response', None
#    5857 ):
#
# File ~/Work/AgenticAI/.agenticai/lib/python3.13/site-packages/google/genai/_api_client.py:1434, in BaseApiClient.async_request(self, http_method, path, request_dict, http_options)
#    1430 http_request = self._build_request(
#    1431     http_method, path, request_dict, http_options
#    1432 )
# -> 1434 result = await self._async_request(
#    1435     http_request=http_request, http_options=http_options, stream=False
#    1436 )
#    1437 response_body = result.response_stream[0] if result.response_stream else ''
#
# File ~/Work/AgenticAI/.agenticai/lib/python3.13/site-packages/google/genai/_api_client.py:1367, in BaseApiClient._async_request(self, http_request, http_options, stream)
#    1366     return await retry(self._async_request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1367 return await self._async_retry(  # type: ignore[no-any-return]
#    1368     self._async_request_once, http_request, stream
#    1369 )
#
# File ~/Work/AgenticAI/.agenticai/lib/python3.13/site-packages/tenacity/asyncio/__init__.py:111, in AsyncRetrying.__call__(self, fn, *args, **kwargs)
#     110 while True:
# --> 111     do = await self.iter(retry_state=retry_state)
#     112     if isinstance(do, DoAttempt):
#
# File ~/Work/AgenticAI/.agenticai/lib/python3.13/site-packages/tenacity/asyncio/__init__.py:153, in AsyncRetrying.iter(self, retry_state)
#     152 for action in self.iter_state.actions:
# --> 153     result = await action(retry_state)
#     154 return result
#
# File ~/Work/AgenticAI/.agenticai/lib/python3.13/site-packages/tenacity/_utils.py:99, in wrap_to_async_func.<locals>.inner(*args, **kwargs)
#      98 async def inner(*args: typing.Any, **kwargs: typing.Any) -> typing.Any:
# ---> 99     return call(*args, **kwargs)
#
# File ~/Work/AgenticAI/.agenticai/lib/python3.13/site-packages/tenacity/__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File ~/Work/AgenticAI/.agenticai/lib/python3.13/site-packages/tenacity/__init__.py:187, in RetryError.reraise(self)
#     186 if self.last_attempt.failed:
# --> 187     raise self.last_attempt.result()
#     188 raise self
#
# File /opt/homebrew/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File ~/Work/AgenticAI/.agenticai/lib/python3.13/site-packages/tenacity/asyncio/__init__.py:114, in AsyncRetrying.__call__(self, fn, *args, **kwargs)
#     113 try:
# --> 114     result = await fn(*args, **kwargs)
#     115 except BaseException:  # noqa: B902
#
# File ~/Work/AgenticAI/.agenticai/lib/python3.13/site-packages/google/genai/_api_client.py:1347, in BaseApiClient._async_request_once(self, http_request, stream)
#    1340 client_response = await self._async_httpx_client.request(
#    1341     method=http_request.method,
#    1342     url=http_request.url,
#    (...)   1345     timeout=http_request.timeout,
#    1346 )
# -> 1347 await errors.APIError.raise_for_async_response(client_response)
#    1348 return HttpResponse(client_response.headers, [client_response.text])
#
# File ~/Work/AgenticAI/.agenticai/lib/python3.13/site-packages/google/genai/errors.py:203, in APIError.raise_for_async_response(cls, response)
#     201     raise ValueError(f'Unsupported response type: {type(response)}')
# --> 203 await cls.raise_error_async(status_code, response_json, response)
#
# File ~/Work/AgenticAI/.agenticai/lib/python3.13/site-packages/google/genai/errors.py:225, in APIError.raise_error_async(cls, status_code, response_json, response)
#     224 if 400 <= status_code < 500:
# --> 225   raise ClientError(status_code, response_json, response)
#     226 elif 500 <= status_code < 600:
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite\nPlease retry in 51.145040302s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '51s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# _ResourceExhaustedError                   Traceback (most recent call last)
# Cell In[29], line 2
#       1 runner = InMemoryRunner(agent=root_agent)
# ----> 2 response = await runner.run_debug("Write a short story about a lighthouse keeper who discovers a mysterious, glowing map")
#
# File ~/Work/AgenticAI/.agenticai/lib/python3.13/site-packages/google/adk/runners.py:1168, in Runner.run_debug(self, user_messages, user_id, session_id, run_config, quiet, verbose)
#    1165 if not quiet:
#    1166   print(f'\nUser > {message}')
# -> 1168 async for event in self.run_async(
#    1169     user_id=user_id,
#    1170     session_id=session.id,
#    1171     new_message=types.UserContent(parts=[types.Part(text=message)]),
#    1172     run_config=run_config,
#    1173 ):
#    1174   if not quiet:
#    1175     print_event(event, verbose=verbose)
#
# File ~/Work/AgenticAI/.agenticai/lib/python3.13/site-packages/google/adk/runners.py:505, in Runner.run_async(self, user_id, session_id, invocation_id, new_message, state_delta, run_config)
#     500       await _run_compaction_for_sliding_window(
#     501           self.app, session, self.session_service
#     502       )
#     504 async with Aclosing(_run_with_trace(new_message, invocation_id)) as agen:
# --> 505   async for event in agen:
#     506     yield event
#
# File ~/Work/AgenticAI/.agenticai/lib/python3.13/site-packages/google/adk/runners.py:493, in Runner.run_async.<locals>._run_with_trace(new_message, invocation_id)
#     483       yield event
#     485 async with Aclosing(
#     486     self._exec_with_plugin(
#     487         invocation_context=invocation_context,
#    (...)    491     )
#     492 ) as agen:
# --> 493   async for event in agen:
#     494     yield event
#     495 # Run compaction after all events are yielded from the agent.
#     496 # (We don't compact in the middle of an invocation, we only compact at
#     497 # the end of an invocation.)
#
# File ~/Work/AgenticAI/.agenticai/lib/python3.13/site-packages/google/adk/runners.py:722, in Runner._exec_with_plugin(self, invocation_context, session, execute_fn, is_live_call)
#     719 is_transcribing: bool = False
#     721 async with Aclosing(execute_fn(invocation_context)) as agen:
# --> 722   async for event in agen:
#     723     if is_live_call:
#     724       if event.partial and _is_transcription(event):
#
# File ~/Work/AgenticAI/.agenticai/lib/python3.13/site-packages/google/adk/runners.py:482, in Runner.run_async.<locals>._run_with_trace.<locals>.execute(ctx)
#     480 async def execute(ctx: InvocationContext) -> AsyncGenerator[Event]:
#     481   async with Aclosing(ctx.agent.run_async(ctx)) as agen:
# --> 482     async for event in agen:
#     483       yield event
#
# File ~/Work/AgenticAI/.agenticai/lib/python3.13/site-packages/google/adk/agents/base_agent.py:294, in BaseAgent.run_async(self, parent_context)
#     291   return
#     293 async with Aclosing(self._run_async_impl(ctx)) as agen:
# --> 294   async for event in agen:
#     295     yield event
#     297 if ctx.end_invocation:
#
# File ~/Work/AgenticAI/.agenticai/lib/python3.13/site-packages/google/adk/agents/sequential_agent.py:77, in SequentialAgent._run_async_impl(self, ctx)
#      74     yield self._create_agent_state_event(ctx)
#      76 async with Aclosing(sub_agent.run_async(ctx)) as agen:
# ---> 77   async for event in agen:
#      78     yield event
#      79     if ctx.should_pause_invocation(event):
#
# File ~/Work/AgenticAI/.agenticai/lib/python3.13/site-packages/google/adk/agents/base_agent.py:294, in BaseAgent.run_async(self, parent_context)
#     291   return
#     293 async with Aclosing(self._run_async_impl(ctx)) as agen:
# --> 294   async for event in agen:
#     295     yield event
#     297 if ctx.end_invocation:
#
# File ~/Work/AgenticAI/.agenticai/lib/python3.13/site-packages/google/adk/agents/llm_agent.py:460, in LlmAgent._run_async_impl(self, ctx)
#     458 should_pause = False
#     459 async with Aclosing(self._llm_flow.run_async(ctx)) as agen:
# --> 460   async for event in agen:
#     461     self.__maybe_save_output_to_state(event)
#     462     yield event
#
# File ~/Work/AgenticAI/.agenticai/lib/python3.13/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:370, in BaseLlmFlow.run_async(self, invocation_context)
#     368 last_event = None
#     369 async with Aclosing(self._run_one_step_async(invocation_context)) as agen:
# --> 370   async for event in agen:
#     371     last_event = event
#     372     yield event
#
# File ~/Work/AgenticAI/.agenticai/lib/python3.13/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:447, in BaseLlmFlow._run_one_step_async(self, invocation_context)
#     436 model_response_event = Event(
#     437     id=Event.new_id(),
#     438     invocation_id=invocation_context.invocation_id,
#     439     author=invocation_context.agent.name,
#     440     branch=invocation_context.branch,
#     441 )
#     442 async with Aclosing(
#     443     self._call_llm_async(
#     444         invocation_context, llm_request, model_response_event
#     445     )
#     446 ) as agen:
# --> 447   async for llm_response in agen:
#     448     # Postprocess after calling the LLM.
#     449     async with Aclosing(
#     450         self._postprocess_async(
#     451             invocation_context,
#    (...)    455         )
#     456     ) as agen:
#     457       async for event in agen:
#     458         # Update the mutable event id to avoid conflict
#
# File ~/Work/AgenticAI/.agenticai/lib/python3.13/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:816, in BaseLlmFlow._call_llm_async(self, invocation_context, llm_request, model_response_event)
#     813           yield llm_response
#     815 async with Aclosing(_call_llm_with_tracing()) as agen:
# --> 816   async for event in agen:
#     817     yield event
#
# File ~/Work/AgenticAI/.agenticai/lib/python3.13/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:800, in BaseLlmFlow._call_llm_async.<locals>._call_llm_with_tracing()
#     787 responses_generator = llm.generate_content_async(
#     788     llm_request,
#     789     stream=invocation_context.run_config.streaming_mode
#     790     == StreamingMode.SSE,
#     791 )
#     792 async with Aclosing(
#     793     self._run_and_handle_error(
#     794         responses_generator,
#    (...)    798     )
#     799 ) as agen:
# --> 800   async for llm_response in agen:
#     801     trace_call_llm(
#     802         invocation_context,
#     803         model_response_event.id,
#     804         llm_request,
#     805         llm_response,
#     806     )
#     807     # Runs after_model_callback if it exists.
#
# File ~/Work/AgenticAI/.agenticai/lib/python3.13/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:1053, in BaseLlmFlow._run_and_handle_error(self, response_generator, invocation_context, llm_request, model_response_event)
#    1051   yield error_response
#    1052 else:
# -> 1053   raise model_error
#
# File ~/Work/AgenticAI/.agenticai/lib/python3.13/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:1039, in BaseLlmFlow._run_and_handle_error(self, response_generator, invocation_context, llm_request, model_response_event)
#    1037 try:
#    1038   async with Aclosing(response_generator) as agen:
# -> 1039     async for response in agen:
#    1040       yield response
#    1041 except Exception as model_error:
#
# File ~/Work/AgenticAI/.agenticai/lib/python3.13/site-packages/google/adk/models/google_llm.py:260, in Gemini.generate_content_async(self, llm_request, stream)
#     255 except ClientError as ce:
#     256   if ce.code == 429:
#     257     # We expect running into a Resource Exhausted error to be a common
#     258     # client error that developers would run into. We enhance the messaging
#     259     # with possible fixes to this issue.
# --> 260     raise _ResourceExhaustedError(ce) from ce
#     262   raise ce
#
# _ResourceExhaustedError:
# On how to mitigate this issue, please refer to:
#
# https://google.github.io/adk-docs/agents/models/#error-code-429-resource_exhausted
#
#
# 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite\nPlease retry in 51.145040302s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '51s'}]}}
